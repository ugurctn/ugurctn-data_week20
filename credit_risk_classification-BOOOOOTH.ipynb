# %%
 # Import the required modules
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, roc_curve, RocCurveDisplay

# Preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split

# suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/ugurcetin/Desktop//lending_data.csv')
df.head()
# Out:
#    loan_size  interest_rate  borrower_income  debt_to_income  num_of_accounts  \
# 0    10700.0          7.672            52800        0.431818                5
# 1     8400.0          6.692            43600        0.311927                3
# 2     9000.0          6.963            46100        0.349241                3
# 3    10700.0          7.664            52700        0.430740                5
# 4    10800.0          7.698            53000        0.433962                5
#
#    derogatory_marks  total_debt  loan_status
# 0                 1       22800            0
# 1                 0       13600            0
# 2                 0       16100            0
# 3                 1       22700            0
# 4                 1       23000            0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77536 entries, 0 to 77535
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   loan_size         77536 non-null  float64
#  1   interest_rate     77536 non-null  float64
#  2   borrower_income   77536 non-null  int64
#  3   debt_to_income    77536 non-null  float64
#  4   num_of_accounts   77536 non-null  int64
#  5   derogatory_marks  77536 non-null  int64
#  6   total_debt        77536 non-null  int64
#  7   loan_status       77536 non-null  int64
# dtypes: float64(3), int64(5)
# memory usage: 4.7 MB

# %%
# NO NULLs
# No encoding

# %%
df.describe()
# Out:
#           loan_size  interest_rate  borrower_income  debt_to_income  \
# count  77536.000000   77536.000000     77536.000000    77536.000000
# mean    9805.562577       7.292333     49221.949804        0.377318
# std     2093.223153       0.889495      8371.635077        0.081519
# min     5000.000000       5.250000     30000.000000        0.000000
# 25%     8700.000000       6.825000     44800.000000        0.330357
# 50%     9500.000000       7.172000     48100.000000        0.376299
# 75%    10400.000000       7.528000     51400.000000        0.416342
# max    23800.000000      13.235000    105200.000000        0.714829
#
#        num_of_accounts  derogatory_marks    total_debt   loan_status
# count     77536.000000      77536.000000  77536.000000  77536.000000
# mean          3.826610          0.392308  19221.949804      0.032243
# std           1.904426          0.582086   8371.635077      0.176646
# min           0.000000          0.000000      0.000000      0.000000
# ...

# %%
# We need a scaler

# %%
df.loan_status.value_counts()
# Out:
# loan_status
# 0    75036
# 1     2500
# Name: count, dtype: int64

# %%
# SEVERE IMBALANCE
# FIRST: the model will be pretty good at predicting the dominant class (sample size)
# We care about 1 not 0 though :(
# this could mean trouble

# SECOND: Accuracy score is not going to be helpful. If I ONLY predict 0s, I am 97% accurate
# We care about FN, I am going to prioritize Recall as a metric

# TO:DO - Try over/under sampling technique or SMOTE

# %%
75036 / 77536
# Out:
# 0.9677569129178704

# %%
# Feature selection
# correlation analysis
corrs = df.corr()
corrs
# Out:
#                   loan_size  interest_rate  borrower_income  debt_to_income  \
# loan_size          1.000000       0.999905         0.999893        0.951847
# interest_rate      0.999905       1.000000         0.999994        0.951938
# borrower_income    0.999893       0.999994         1.000000        0.951950
# debt_to_income     0.951847       0.951938         0.951950        1.000000
# num_of_accounts    0.988507       0.988515         0.988509        0.941078
# derogatory_marks   0.840407       0.840596         0.840577        0.825668
# total_debt         0.999893       0.999994         1.000000        0.951950
# loan_status        0.758846       0.758900         0.758890        0.589305
#
#                   num_of_accounts  derogatory_marks  total_debt  loan_status
# loan_size                0.988507          0.840407    0.999893     0.758846
# interest_rate            0.988515          0.840596    0.999994     0.758900
# ...

# %%
sns.heatmap(corrs, annot=True)
plt.show()

# %%
# We have STRONG linear relationships with the target (loan_status)
# LINEAR MODELS should actually be pretty decent
# BECAUSE of the severe multicollinearity - want to make sure we regularize the model OR use PCA
# L1 or L2 - send the coefficients to 0 or approaching 0
# Luckily, this is the default for LogisticRegression in scikit learn

# %% [markdown]
# # Preprocessing

# %%
df.columns
# Out:
# Index(['loan_size', 'interest_rate', 'borrower_income', 'debt_to_income',
#        'num_of_accounts', 'derogatory_marks', 'total_debt', 'loan_status'],
#       dtype='object')

# %%
num_cols = ['loan_size', 'interest_rate', 'borrower_income', 'debt_to_income',
       'num_of_accounts', 'derogatory_marks', 'total_debt']

# Initalize and Fit the Scaler
ss = StandardScaler()
ss.fit(df.loc[:, num_cols])

# Transform the Data
df_scaled = pd.DataFrame(ss.transform(df.loc[:, num_cols]), columns=num_cols)
df_scaled.head()
# Out:
#    loan_size  interest_rate  borrower_income  debt_to_income  num_of_accounts  \
# 0   0.427304       0.426837         0.427404        0.668571         0.616143
# 1  -0.671487      -0.674918        -0.671552       -0.802166        -0.434049
# 2  -0.384846      -0.370249        -0.372922       -0.344424        -0.434049
# 3   0.427304       0.417844         0.415459        0.655346         0.616143
# 4   0.475078       0.456068         0.451295        0.694873         0.616143
#
#    derogatory_marks  total_debt
# 0          1.043996    0.427404
# 1         -0.673973   -0.671552
# 2         -0.673973   -0.372922
# 3          1.043996    0.415459
# 4          1.043996    0.451295

# %%
df_scaled.describe()
# Out:
#           loan_size  interest_rate  borrower_income  debt_to_income  \
# count  77536.000000   7.753600e+04     77536.000000    7.753600e+04
# mean       0.000000  -1.407596e-15         0.000000   -1.196457e-15
# std        1.000006   1.000006e+00         1.000006    1.000006e+00
# min       -2.295787  -2.296073e+00        -2.296096   -4.628640e+00
# 25%       -0.528166  -5.253942e-01        -0.528210   -5.760741e-01
# 50%       -0.145978  -1.352827e-01        -0.134019   -1.249033e-02
# 75%        0.283984   2.649469e-01         0.260172    4.787266e-01
# max        6.685636   6.680987e+00         6.686676    4.140328e+00
#
#        num_of_accounts  derogatory_marks    total_debt
# count     7.753600e+04      7.753600e+04  77536.000000
# mean     -4.691987e-17     -5.864983e-17      0.000000
# std       1.000006e+00      1.000006e+00      1.000006
# min      -2.009337e+00     -6.739731e-01     -2.296096
# 25%      -4.340494e-01     -6.739731e-01     -0.528210
# ...

# %% [markdown]
# # Machine Learning

# %%
# Step 1: Get the Data
X = df_scaled
y = df.loan_status

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y) # stratify ensures same % of the target classes in the train/test

print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (77536, 7)
# (58152, 7)
# (19384, 7)

# %%
# Function for Classification
# THE ROC CURVE CODE WILL BREAK FOR MULTI_CLASS PROBLEMS
def doClassification(model, X_train, X_test, y_train, y_test):
    # Step 3: Fit the model
    model.fit(X_train, y_train)
    
    # Step 4: Evaluate the model
    train_preds = model.predict(X_train)
    test_preds = model.predict(X_test)

    train_proba = model.predict_proba(X_train)[:, 1]
    test_proba = model.predict_proba(X_test)[:, 1]

    # Generate metrics TRAIN
    train_cf = confusion_matrix(y_train, train_preds)
    train_cr = classification_report(y_train, train_preds)
    train_auc = roc_auc_score(y_train, train_proba)
    
    train_results = f"""TRAIN METRICS
    Confusion Matrix: 
    {train_cf}
    
    AUC: {train_auc}

    Classification Report:
    {train_cr}
    """
    
    print(train_results)

    # Generate metrics TEST
    test_cf = confusion_matrix(y_test, test_preds)
    test_cr = classification_report(y_test, test_preds)
    test_auc = roc_auc_score(y_test, test_proba)
    
    test_results = f"""TEST METRICS
    Confusion Matrix: 
    {test_cf}
    
    AUC: {test_auc}

    Classification Report:
    {test_cr}
    """
    
    print(test_results)

    # VISUALIZE TEST RESULTS
    # Confusion Matrix
    plt.figure(figsize=(4, 4))
    sns.heatmap(test_cf, annot=True, fmt='d', cmap='Blues', cbar=False, 
                xticklabels=['Predicted Negative', 'Predicted Positive'], 
                yticklabels=['Actual Negative', 'Actual Positive'])
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

    # ROC Curve
    fpr, tpr, _ = roc_curve(y_test.values, test_proba)
    
    # Set figure size
    plt.figure(figsize=(6, 6))
    
    # Plot the ROC curve
    plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {test_auc:.2f})')
    
    # Plot the diagonal reference line
    plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
    
    # Titles and labels
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    
    # Add grid and legend
    plt.grid(linestyle="--", color="lightgrey", alpha=0.75)
    plt.legend(loc="lower right")
    
    # Display the plot
    plt.show()

# %%
# Step 2: Init the Model
# lr = LogisticRegression(penalty="l1", solver="liblinear")
lr = LogisticRegression()

# Do Machine Learning
doClassification(lr, X_train, X_test, y_train, y_test)
# Out:
# TRAIN METRICS
#     Confusion Matrix:
#     [[55953   324]
#  [   34  1841]]
#
#     AUC: 0.9941686206916975
#
#     Classification Report:
#                   precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56277
#            1       0.85      0.98      0.91      1875
#
#     accuracy                           0.99     58152
#    macro avg       0.92      0.99      0.95     58152
# weighted avg       0.99      0.99      0.99     58152
#
#
# TEST METRICS
#     Confusion Matrix:
#     [[18673    86]
#  [   11   614]]
#
#     AUC: 0.9969859374167067
#
#     Classification Report:
#                   precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     18759
#            1       0.88      0.98      0.93       625
#
#     accuracy                           0.99     19384
#    macro avg       0.94      0.99      0.96     19384
# weighted avg       1.00      0.99      1.00     19384

# %%
# this fits really well with no overfitting - DESPITE being imbalanced

# %%
# Step 2: Init the Model
knn = KNeighborsClassifier(n_neighbors=7)

# Do Machine Learning
doClassification(knn, X_train, X_test, y_train, y_test)
# Out:
# TRAIN METRICS
#     Confusion Matrix:
#     [[55956   321]
#  [   21  1854]]
#
#     AUC: 0.9970389987620756
#
#     Classification Report:
#                   precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56277
#            1       0.85      0.99      0.92      1875
#
#     accuracy                           0.99     58152
#    macro avg       0.93      0.99      0.96     58152
# weighted avg       0.99      0.99      0.99     58152
#
#
# TEST METRICS
#     Confusion Matrix:
#     [[18674    85]
#  [    9   616]]
#
#     AUC: 0.997150466442774
#
#     Classification Report:
#                   precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     18759
#            1       0.88      0.99      0.93       625
#
#     accuracy                           1.00     19384
#    macro avg       0.94      0.99      0.96     19384
# weighted avg       1.00      1.00      1.00     19384

# %%
 # Step 2: Init the Model
rf = RandomForestClassifier(random_state=42)

# Do Machine Learning
doClassification(rf, X_train, X_test, y_train, y_test)
# Out:
# TRAIN METRICS
#     Confusion Matrix:
#     [[56142   135]
#  [   32  1843]]
#
#     AUC: 0.9997961464423003
#
#     Classification Report:
#                   precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56277
#            1       0.93      0.98      0.96      1875
#
#     accuracy                           1.00     58152
#    macro avg       0.97      0.99      0.98     58152
# weighted avg       1.00      1.00      1.00     58152
#
#
# TEST METRICS
#     Confusion Matrix:
#     [[18683    76]
#  [   72   553]]
#
#     AUC: 0.9972441601364678
#
#     Classification Report:
#                   precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     18759
#            1       0.88      0.88      0.88       625
#
#     accuracy                           0.99     19384
#    macro avg       0.94      0.94      0.94     19384
# weighted avg       0.99      0.99      0.99     19384

# %%
# Little bit of overfitting but worse than logistic anyway

# %%
# !pip install xgboost lightgbm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.6 MB/s eta 0:00:0000:0100:010m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 1.1 MB/s eta 0:00:0000:0100:010m
# ...

# %%
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
# Step 2: Init the Model
xgb = XGBClassifier(random_state=42)

# Do Machine Learning
doClassification(xgb, X_train, X_test, y_train, y_test)
# Out:
# TRAIN METRICS
#     Confusion Matrix:
#     [[55952   325]
#  [   14  1861]]
#
#     AUC: 0.9977823646131339
#
#     Classification Report:
#                   precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56277
#            1       0.85      0.99      0.92      1875
#
#     accuracy                           0.99     58152
#    macro avg       0.93      0.99      0.96     58152
# weighted avg       0.99      0.99      0.99     58152
#
#
# TEST METRICS
#     Confusion Matrix:
#     [[18672    87]
#  [    5   620]]
#
#     AUC: 0.9976339037262113
#
#     Classification Report:
#                   precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     18759
#            1       0.88      0.99      0.93       625
#
#     accuracy                           1.00     19384
#    macro avg       0.94      0.99      0.96     19384
# weighted avg       1.00      1.00      1.00     19384

# %%
# Step 2: Init the Model
lgbm = LGBMClassifier(random_state=42, verbose=-1)

# Do Machine Learning
doClassification(lgbm, X_train, X_test, y_train, y_test)
# Out:
# TRAIN METRICS
#     Confusion Matrix:
#     [[55958   319]
#  [   18  1857]]
#
#     AUC: 0.9981545569237875
#
#     Classification Report:
#                   precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56277
#            1       0.85      0.99      0.92      1875
#
#     accuracy                           0.99     58152
#    macro avg       0.93      0.99      0.96     58152
# weighted avg       0.99      0.99      0.99     58152
#
#
# TEST METRICS
#     Confusion Matrix:
#     [[18673    86]
#  [    7   618]]
#
#     AUC: 0.9975213604136682
#
#     Classification Report:
#                   precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     18759
#            1       0.88      0.99      0.93       625
#
#     accuracy                           1.00     19384
#    macro avg       0.94      0.99      0.96     19384
# weighted avg       1.00      1.00      1.00     19384

# %%
fi = pd.DataFrame(list(zip(X.columns, xgb.feature_importances_)), columns=["Feature", "Importance"])
fi.sort_values(by="Importance", ascending=False)
# Out:
#             Feature  Importance
# 0         loan_size    0.992188
# 1     interest_rate    0.002743
# 4   num_of_accounts    0.002738
# 2   borrower_income    0.002297
# 5  derogatory_marks    0.000034
# 3    debt_to_income    0.000000
# 6        total_debt    0.000000

# %%
fi = pd.DataFrame(list(zip(X.columns, lgbm.feature_importances_ / sum(lgbm.feature_importances_))), columns=["Feature", "Importance"])
fi.sort_values(by="Importance", ascending=False)
# Out:
#             Feature  Importance
# 0         loan_size    0.407333
# 2   borrower_income    0.234667
# 1     interest_rate    0.221667
# 3    debt_to_income    0.121333
# 4   num_of_accounts    0.012000
# 5  derogatory_marks    0.003000
# 6        total_debt    0.000000

# %%
# Conclusions

# Logistic regression performed well with regularization. It is the most explainable
# KNN performed well and is explainable - but is slow and data is large
# Random forest overfits and performs worse than the linear model
# XGBOOOST has best metrics BUT, the feature importances are biased
# LGBM looks good with varied feature importances and has comparable performance to XGBOOSt and Logistic

# If explainability and simplicity, the logistic regression works well. 
# The LGBM model might generalize better and have better performance but a sacrifice of explainability

# %% [markdown]
# ---

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %% [markdown]
# ### Step 1: Read the `lending_data.csv` data from the `Resources` folder into a Pandas DataFrame.

# %%
# Import pandas
import pandas as pd

# Read the CSV file
file_path = "/Users/ugurcetin/Desktop//lending_data.csv"
df = pd.read_csv(file_path)

# Review the DataFrame
df.head()
# Out:
#    loan_size  interest_rate  borrower_income  debt_to_income  num_of_accounts  \
# 0    10700.0          7.672            52800        0.431818                5
# 1     8400.0          6.692            43600        0.311927                3
# 2     9000.0          6.963            46100        0.349241                3
# 3    10700.0          7.664            52700        0.430740                5
# 4    10800.0          7.698            53000        0.433962                5
#
#    derogatory_marks  total_debt  loan_status
# 0                 1       22800            0
# 1                 0       13600            0
# 2                 0       16100            0
# 3                 1       22700            0
# 4                 1       23000            0

# %% [markdown]
# ### Step 2: Create the labels set (`y`)  from the “loan_status” column, and then create the features (`X`) DataFrame from the remaining columns.

# %%
# Separate the data into labels and features

# Separate the y variable, the labels
y = df['loan_status']

# Separate the X variable, the features
X = df.drop(columns='loan_status')

# %%
# Review the y variable Series
y.value_counts()
# Out:
# loan_status
# 0    75036
# 1     2500
# Name: count, dtype: int64

# %%
# Review the X variable DataFrame
X.head()
# Out:
#    loan_size  interest_rate  borrower_income  debt_to_income  num_of_accounts  \
# 0    10700.0          7.672            52800        0.431818                5
# 1     8400.0          6.692            43600        0.311927                3
# 2     9000.0          6.963            46100        0.349241                3
# 3    10700.0          7.664            52700        0.430740                5
# 4    10800.0          7.698            53000        0.433962                5
#
#    derogatory_marks  total_debt
# 0                 1       22800
# 1                 0       13600
# 2                 0       16100
# 3                 1       22700
# 4                 1       23000

# %% [markdown]
# ### Step 3: Split the data into training and testing datasets by using `train_test_split`.

# %%
# Import the train_test_learn module
from sklearn.model_selection import train_test_split

# Split the data using train_test_split
# Assign a random_state of 1 to the function
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ---

# %% [markdown]
# ## Create a Logistic Regression Model with the Original Data

# %% [markdown]
# ###  Step 1: Fit a logistic regression model by using the training data (`X_train` and `y_train`).

# %%
# Import the LogisticRegression module from SKLearn
from sklearn.linear_model import LogisticRegression

# Instantiate the Logistic Regression model
# Assign a random_state parameter of 1 to the model
classifier = LogisticRegression(random_state=1)

# Fit the model using training data
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=1)

# %% [markdown]
# ### Step 2: Save the predictions on the testing data labels by using the testing feature data (`X_test`) and the fitted model.

# %%
# Make a prediction using the testing data
y_pred = classifier.predict(X_test)

# %% [markdown]
# ### Step 3: Evaluate the model’s performance by doing the following:
#
# * Generate a confusion matrix.
#
# * Print the classification report.

# %%
# Generate a confusion matrix for the model
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[18655   110]
#  [   36   583]]

# %%
# Print the classification report for the model
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     18765
#            1       0.84      0.94      0.89       619
#
#     accuracy                           0.99     19384
#    macro avg       0.92      0.97      0.94     19384
# weighted avg       0.99      0.99      0.99     19384

# %% [markdown]
# ### Step 4: Answer the following question.

# %% [markdown]
# **Question:** How well does the logistic regression model predict both the `0` (healthy loan) and `1` (high-risk loan) labels?
#
# **Answer:**
# The logistic regression model predicts the 0 (healthy loan) label exceptionally well, with a precision of 1.00, recall of 0.99, and F1-score of 1.00. This means the model is almost perfect at identifying healthy loans.
#
# For the 1 (high-risk loan) label, the model performs well but not as strongly. It has a precision of 0.84, recall of 0.94, and F1-score of 0.89. This indicates that while the model is able to correctly identify most high-risk loans (high recall), it sometimes misclassifies healthy loans as high-risk (lower precision).
#
# Overall, the model demonstrates very high accuracy (0.99) and performs well across both classes, with slightly reduced performance for high-risk loans, which is common in imbalanced datasets.

# %% [markdown]
# ---
